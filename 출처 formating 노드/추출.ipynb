# %%
doc = """
다음은 제공된 문서에 근거한 국민은행 대출 금리의 일반적인 운용 방식입니다.

MOR/COFIX/국고채를 기준으로 약정하는 대출

대출 실행일의 MOR, COFIX, 또는 국고채를 기준으로 이자율이 적용됩니다.
실제로 적용될 이자율은 대출거래장에 표시되며, 개별 통지는 생략될 수 있습니다.
필요시 신청한 고객에 한해 대출실행내역통지 서비스를 통해 개별 통지가 이루어질 수 있습니다.
(출처: 출처 2)
일반 대출(상사법정이율 적용 범위)

은행의 일반 대출은 “상사법정이율”에 따른 연 6%의 범위 내에서 약정 금리가 정해질 수 있습니다.
1년을 365일(윤년은 366일)로 보고 1일 단위로 이자를 계산해 갚아야 합니다.
대출 취급 전에 약정 이자, 기한 도래일 전 상환수수료, 부대비용의 항목과 금액을 서면으로 설명해야 하며, 실질적 유효금리를 함께 설명합니다.
(출처: 출처 3)
주택담보노후연금대출용 대출

이율은 법령 변경 등에 의해 변동될 수 있습니다.
대출 실행일에 결정된 이자율이 MOR인 경우 3개월 주기, 신규취급액기준 COFIX인 경우 6개월 주기로 재산정됩니다.
제2항 제1호, 제2호의 금리 재산정 주기에 MOR 또는 COFIX가 변동되면 대출 이자율도 이에 연동되어 변동합니다.
(출처: 출처 4)
금리 우대(추가약정서) 적용 여부

금리 우대 약정서를 통해 특정 요건 충족 시 우대금리가 적용될 수 있습니다.
우대 상한은 0.5%p이며, 가구 유형에 따라 상한이 다르게 적용될 수 있습니다(예: 신혼가구, 다자녀가구 등).
(출처: 출처 5)
참고 및 정확한 금리 확인 방법

특정 대출의 정확한 금리는 대출 실행 시 작성된 약정서(대출거래약정서)에 기재된 금리 또는 해당 지표에 따라 결정되는 이자율로 확인하셔야 합니다.
필요 시 고객센터나 대출 약정서의 해당 조항을 확인해 주세요.
(출처: 종합적으로 출처 2, 3, 4, 5)
추가로, 우리은행 관련 정보는 제공된 문서에 포함되어 있지 않아 이번 답변은 국민은행에 한해 설명드립니다. 만약 우리은행 대출 금리 규정도 확인을 원하시면 해당 은행의 문서를 추가로 공유해 주세요.
"""

# %%
# 출처 제목
title ={
    0:"국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan)",
    1:"국민은행 - nan (제1조 nan)",
    2:"국민은행 - 은행거래기본약관 (제54조 상사법정이율)",
    3:"국민은행 - Ⅶ 주택담보노후연금대출용 대출거래약정서 (제1조 nan)",
    4:"국민은행 - 금리우대 가계용 추가약정서 (1 금리우대 적용)",
    5:"국민은행 - 금리인하요구권안내 및 핵심상품설명서 (1 개요)",
    6:"국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제1조 nan)",
    7:"국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan)"
}

# %%
# 문서에서 변환 대상 찾기
for sentence in doc.split("\n"):
    if "출처" in sentence:
        print(sentence)
# Out:
# (출처: 출처 2)
# (출처: 출처 3)
# (출처: 출처 4)
# (출처: 출처 5)
# (출처: 종합적으로 출처 2, 3, 4, 5)

# %%
for sentence in doc.split("\n"):
    if "출처" in sentence:
        target = sentence
        for i in range(len(title) - 1, -1, -1):
            target = target.replace(str(i + 1), title[i])
        # 출저: => 뒤에 나오는 "출처" 키워드 중복 제거
        target = target.replace("출처 ", "")
        print(target)
# Out:
# (출처: 국민은행 - nan (제국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan)조 nan))
# (출처: 국민은행 - 은행거래기본약관 (제54조 상사법정이율))
# (출처: 국민은행 - Ⅶ 주택담보노후연금대출용 대출거래약정서 (제국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan)조 nan))
# (출처: 국민은행 - 금리우대 가계용 추가약정서 (국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan) 금리우대 적용))
# (출처: 종합적으로 국민은행 - nan (제국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan)조 nan), 국민은행 - 은행거래기본약관 (제54조 상사법정이율), 국민은행 - Ⅶ 주택담보노후연금대출용 대출거래약정서 (제국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan)조 nan), 국민은행 - 금리우대 가계용 추가약정서 (국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan) 금리우대 적용))

# %%
# 통합 코드
final_doc = ""
for sentence in doc.split("\n"):
    if "출처" in sentence:
        target = sentence
        for i in range(len(title) - 1, -1, -1):
            target = target.replace(str(i + 1), title[i])
        # 출저: => 뒤에 나오는 "출처" 키워드 중복 제거
        target = target.replace("출처 ", "")
        final_doc += target
    else:
        final_doc += sentence
    final_doc += "\n"

print(final_doc)
# Out:
# 다음은 제공된 문서에 근거한 국민은행 대출 금리의 일반적인 운용 방식입니다.
#
# MOR/COFIX/국고채를 기준으로 약정하는 대출
#
# 대출 실행일의 MOR, COFIX, 또는 국고채를 기준으로 이자율이 적용됩니다.
# 실제로 적용될 이자율은 대출거래장에 표시되며, 개별 통지는 생략될 수 있습니다.
# 필요시 신청한 고객에 한해 대출실행내역통지 서비스를 통해 개별 통지가 이루어질 수 있습니다.
# (출처: 국민은행 - nan (제국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan)조 nan))
# 일반 대출(상사법정이율 적용 범위)
#
# 은행의 일반 대출은 “상사법정이율”에 따른 연 6%의 범위 내에서 약정 금리가 정해질 수 있습니다.
# 1년을 365일(윤년은 366일)로 보고 1일 단위로 이자를 계산해 갚아야 합니다.
# 대출 취급 전에 약정 이자, 기한 도래일 전 상환수수료, 부대비용의 항목과 금액을 서면으로 설명해야 하며, 실질적 유효금리를 함께 설명합니다.
# (출처: 국민은행 - 은행거래기본약관 (제54조 상사법정이율))
# 주택담보노후연금대출용 대출
#
# 이율은 법령 변경 등에 의해 변동될 수 있습니다.
# 대출 실행일에 결정된 이자율이 MOR인 경우 3개월 주기, 신규취급액기준 COFIX인 경우 6개월 주기로 재산정됩니다.
# 제2항 제1호, 제2호의 금리 재산정 주기에 MOR 또는 COFIX가 변동되면 대출 이자율도 이에 연동되어 변동합니다.
# (출처: 국민은행 - Ⅶ 주택담보노후연금대출용 대출거래약정서 (제국민은행 - II 종합통장자동대출 및 가계당좌대출용 대출거래약정서 (제9조 nan)조 nan))
# 금리 우대(추가약정서) 적용 여부
#
# 금리 우대 약정서를 통해 특정 요건 충족 시 우대금리가 적용될 수 있습니다.
# 우대 상한은 0.5%p이며, 가구 유형에 따라 상한이 다르게 적용될 수 있습니다(예: 신혼가구, 다자녀가구 등).
# ...

# %%
# 다른 llm 응답
doc = """
다음은 제공된 문서에 근거한 우리은행의 예금 상품들입니다. 문서에 따라 일부는 “특판” 형식의 한시적 판매 상품이고, 다른 하나는 예금의 기본 성격을 정하는 내용입니다.

(특판명)정기예금특약

내용 요약: 이 예금은 특판 형태의 정기예금입니다. 기본이율은 가입일 당시 영업점 및 우리은행 홈페이지에 고시된 이율이 적용됩니다. 출처: 출처 1, 출처 6
우리특판정기예금특약

내용 요약: 이 예금은 은행이 회차별로 별도의 판매기간을 정하여 판매합니다. 판매 기간, 계약기간 또는 판매한도는 영업점과 은행 홈페이지에 게시합니다. 출처: 출처 2
우리행복지킴이통장특약

내용 요약: 예금의 예금과목은 저축예금으로 정해져 있습니다. 출처: 출처 7
(특판 명)정기예금 특약

내용 요약: 이 예금은 은행이 별도의 판매기간과 판매한도, 이율을 정하여 판매합니다. 가입 금액 및 가입기간, 가입방법은 영업점과 우리은행 홈페이지에 고시합니다. 출처: 출처 4
우리 특판 정기 예금

내용 요약: 이 예금은 은행이 회차별로 별도의 판매기간을 정하여 판매합니다. 다만 판매 기간, 계약기간 또는 판매한도는 영업점과 은행 홈페이지에 게시합니다. 출처: 출처 5
제한사항 및 주의 점

제 15조(제한사항): 이 예금은 공동명의로 가입할 수 없습니다. 출처: 출처 8
참고로, 각 항목은 문서에서 “특판” 또는 “특약”으로 분류된 예금 형태이며, 판매 기간/한도/이율 등의 세부 내용은 영업점과 은행 홈페이지에 게시된 정보를 확인하도록 되어 있습니다. 필요한 경우 특정 상품의 자세한 출시 시점, 가입 방법, 필요 서류 등은 영업점에 문의해 확인하시길 권합니다.
"""

# %%
# 출처 제목
title ={
    0:"우리은행 - (특판명)정기예금특약 (제 9조 기본이율)",
    1:"우리은행 - 우리특판정기예금특약 (제 2조 상품정의)",
    2:"우리은행 - 『 우 리 행 복 지 킴 이 통 장 』 특 약 (제2조 nan)",
    3:"우리은행 - 「 ( 특 판 명 ) 정 기 예 금 」 특 약 (제2조 nan)",
    4:"우리은행 - 「 우 리 특 판 정 기 예 금 」 특 약 (제2조 nan)",
    5:"우리은행 - (특판명)정기예금특약 (제 2조 상품정의)",
    6:"우리은행 - 우리행복지킴이통장특약 (제 2조 예금과목)",
    7:"우리은행 - 우리특판정기예금특약 (제 15조 제한사항)"
}

# %%
# 통합 코드
final_doc = ""
for sentence in doc.split("\n"):
    if "출처" in sentence:
        target = sentence
        for i in range(len(title) - 1, -1, -1):
            target = target.replace(str(i + 1), title[i])
        # 출저: => 뒤에 나오는 "출처" 키워드 중복 제거
        target = target.replace("출처 ", "")
        final_doc += target
    else:
        final_doc += sentence
    final_doc += "\n"

print(final_doc)
# Out:
# 다음은 제공된 문서에 근거한 우리은행의 예금 상품들입니다. 문서에 따라 일부는 “특판” 형식의 한시적 판매 상품이고, 다른 하나는 예금의 기본 성격을 정하는 내용입니다.
#
# (특판명)정기예금특약
#
# 내용 요약: 이 예금은 특판 형태의 정기예금입니다. 기본이율은 가입일 당시 영업점 및 우리은행 홈페이지에 고시된 이율이 적용됩니다. 출처: 우리은행 - (특판명)정기예금특약 (제 9조 기본이율), 우리은행 - (특판명)정기예금특약 (제 우리은행 - 우리특판정기예금특약 (제 2조 상품정의)조 상품정의)
# 우리특판정기예금특약
#
# 내용 요약: 이 예금은 은행이 회차별로 별도의 판매기간을 정하여 판매합니다. 판매 기간, 계약기간 또는 판매한도는 영업점과 은행 홈페이지에 게시합니다. 출처: 우리은행 - 우리특판정기예금특약 (제 2조 상품정의)
# 우리행복지킴이통장특약
#
# 내용 요약: 예금의 예금과목은 저축예금으로 정해져 있습니다. 출처: 우리은행 - 우리행복지킴이통장특약 (제 우리은행 - 우리특판정기예금특약 (제 2조 상품정의)조 예금과목)
# (특판 명)정기예금 특약
#
# 내용 요약: 이 예금은 은행이 별도의 판매기간과 판매한도, 이율을 정하여 판매합니다. 가입 금액 및 가입기간, 가입방법은 영업점과 우리은행 홈페이지에 고시합니다. 출처: 우리은행 - 「 ( 특 판 명 ) 정 기 예 금 」 특 약 (제우리은행 - 우리특판정기예금특약 (제 2조 상품정의)조 nan)
# 우리 특판 정기 예금
#
# 내용 요약: 이 예금은 은행이 회차별로 별도의 판매기간을 정하여 판매합니다. 다만 판매 기간, 계약기간 또는 판매한도는 영업점과 은행 홈페이지에 게시합니다. 출처: 우리은행 - 「 우 리 특 판 정 기 예 금 」 특 약 (제우리은행 - 우리특판정기예금특약 (제 2조 상품정의)조 nan)
# 제한사항 및 주의 점
#
# ...

# %%
doc = """
다음은 제공된 우리은행 관련 문서들을 바탕으로 정리한 "우리은행 예금 상품" 목록입니다. 각 항목마다 해당 출처를 함께 명시했습니다.

(특판명)정기예금특약
내용 요지: 은행이 별도의 판매기간과 판매한도, 이율을 정하여 판매합니다. 가입 금액/가입기간/가입방법은 영업점과 우리은행 홈페이지에 고시합니다.
금리 관련: 기본이율은 가입일 당시 영업점 및 홈페이지에 고시된 이율을 적용합니다. 신규 시점의 기본금리 적용에 관한 조항도 존재합니다.
기타 참고: 제15조(제한사항)에서 공동명의로 가입할 수 없다는 내용이 붙을 수 있습니다.
출처: [출처 1], [출처 10], [출처 8], [출처 6], [출처 9]
우리특판정기예금특약
내용 요지: 회차별로 별도의 판매기간을 정하여 판매합니다. 단, 판매 기간/계약기간 또는 판매한도는 영업점과 은행 홈페이지에 게시합니다.
금리 관련: 기본금리는 신규 시점 영업점 및 홈페이지에 고시된 금리가 적용됩니다.
제한사항: 공동명의로 가입할 수 없다는 내용이 포함될 수 있습니다(해당 조항은 제15조에 명시될 수 있습니다).
출처: [출처 2], [출처 10], [출처 8]
우리행복지킴이통장특약
예금 과목: 이 예금의 예금과목은 저축예금으로 합니다.
특징 요약: 저축성 예금(저축예금)으로 가입하는 특약형 통장 형태의 예금 상품입니다.
출처: [출처 7]
「 ( 특 판 명 ) 정 기 예 금 」 특 약
내용 요지: 이 예금은 은행이 별도의 판매기간과 판매한도, 이율을 정하여 판매하며 가입 금액 및 가입기간, 가입방법은 영업점과 은행 홈페이지에 고시합니다.
주의점: 상품명에 "(특판명)"이 들어가 실제 판매 시 은행이 정한 상품명을 사용할 수 있습니다.
출처: [출처 4], [출처 9]
「 우 리 특 판 정 기 예 금 」 특 약
내용 요지: 은행이 회차별로 별도의 판매기간을 정하여 판매합니다. 다만 판매 기간/계약기간 또는 판매한도는 영업점과 은행 홈페이지에 게시합니다.
참고: 이 역시 특판형 정기예금 관련 문서에 해당합니다.
출처: [출처 5], [출처 6], [출처 9]
우 리 국 민 연 금 우 대 통 장 특 약
내용 요지: 이 예금의 전환 규정이 있으며, 일반적으로 저축예금인 경우 다른 예금에서 이 예금으로 전환하거나 이 예금에서 다른 예금으로 전환하는 것이 가능합니다.
특징 요약: 전환 가능성 등 특약상의 전환 규정이 명시됩니다.
출처: [출처 11]
참고 및 주의사항

본 답변은 제공된 문서에 명시된 내용에 한해 정리했습니다. 문서에 따라 각 조항의 구체 내용이 다를 수 있으며, 실제 가입 시점의 고시 이율이나 특정 제약(예: 공동명의 불가 여부)은 해당 상품의 최신 고시 문서를 확인하시기 바랍니다.
금리와 관련된 상세 규정은 각 상품의 기본금리/기본이율 조항에 따라 달라질 수 있습니다. 신규 시점에 적용되는 기본금리 규정은 문서에 명시되어 있습니다. 필요 시 가입 시점의 고시 금리를 확인해 주세요.
만약 특정 상품의 이름이나 조항이 다르게 표기되었다고 느껴지더라도, 제공된 문서의 동일한 실무 규정(예: 판매기간 고시, 전환 여부 등)을 반영한 요약입니다.
필요하시면 위의 각 상품에 대한 구체 조항 번호나 더 자세한 문구를 발췌해 드리겠습니다.
"""

# %%
# 출처 제목
title ={
    0:"우리은행 - (특판명)정기예금특약 (제 9조 기본이율)",
    1:"우리은행 - 우리특판정기예금특약 (제 2조 상품정의)",
    2:"우리은행 - 『 우 리 행 복 지 킴 이 통 장 』 특 약 (제2조 nan)",
    3:"우리은행 - 「 ( 특 판 명 ) 정 기 예 금 」 특 약 (제2조 nan)",
    4:"우리은행 - 「 우 리 특 판 정 기 예 금 」 특 약 (제2조 nan)",
    5:"우리은행 - (특판명)정기예금특약 (제 2조 상품정의)",
    6:"우리은행 - 우리행복지킴이통장특약 (제 2조 예금과목)",
    7:"우리은행 - 우리특판정기예금특약 (제 15조 제한사항)",
    8:"우리은행 - 「 ( 특 판 명 ) 정 기 예 금 」 특 약 (제3조 nan)",
    9:"우리은행 - 우리특판정기예금특약 (제 7조 기본금리)",
    10:"우리은행 - 「 우 리 국 민 연 금 우 대 통 장 」 특 약 (제9조 nan)"
}

# %%
# 통합 코드
final_doc = ""
for sentence in doc.split("\n"):
    if "출처" in sentence:
        target = sentence
        for i in range(len(title) - 1, -1, -1):
            target = target.replace(str(i + 1), title[i])
        # 출저: => 뒤에 나오는 "출처" 키워드 중복 제거
        target = target.replace("출처 ", "")
        final_doc += target
    else:
        final_doc += sentence
    final_doc += "\n"

print(final_doc)
# Out:
# 다음은 제공된 우리은행 관련 문서들을 바탕으로 정리한 "우리은행 예금 상품" 목록입니다. 각 항목마다 해당 출처를 함께 명시했습니다.
#
# (특판명)정기예금특약
# 내용 요지: 은행이 별도의 판매기간과 판매한도, 이율을 정하여 판매합니다. 가입 금액/가입기간/가입방법은 영업점과 우리은행 홈페이지에 고시합니다.
# 금리 관련: 기본이율은 가입일 당시 영업점 및 홈페이지에 고시된 이율을 적용합니다. 신규 시점의 기본금리 적용에 관한 조항도 존재합니다.
# 기타 참고: 제15조(제한사항)에서 공동명의로 가입할 수 없다는 내용이 붙을 수 있습니다.
# 출처: [우리은행 - (특판명)정기예금특약 (제 9조 기본이율)], [우리은행 - 우리특판정기예금특약 (제 우리은행 - 우리행복지킴이통장특약 (제 우리은행 - 우리특판정기예금특약 (제 2조 상품정의)조 예금과목)조 기본금리)], [우리은행 - 우리특판정기예금특약 (제 우리은행 - (특판명)정기예금특약 (제 9조 기본이율)우리은행 - 「 우 리 특 판 정 기 예 금 」 특 약 (제우리은행 - 우리특판정기예금특약 (제 2조 상품정의)조 nan)조 제한사항)], [우리은행 - (특판명)정기예금특약 (제 우리은행 - 우리특판정기예금특약 (제 2조 상품정의)조 상품정의)], [우리은행 - 「 ( 특 판 명 ) 정 기 예 금 」 특 약 (제우리은행 - 『 우 리 행 복 지 킴 이 통 장 』 특 약 (제우리은행 - 우리특판정기예금특약 (제 2조 상품정의)조 nan)조 nan)]
# 우리특판정기예금특약
# 내용 요지: 회차별로 별도의 판매기간을 정하여 판매합니다. 단, 판매 기간/계약기간 또는 판매한도는 영업점과 은행 홈페이지에 게시합니다.
# 금리 관련: 기본금리는 신규 시점 영업점 및 홈페이지에 고시된 금리가 적용됩니다.
# 제한사항: 공동명의로 가입할 수 없다는 내용이 포함될 수 있습니다(해당 조항은 제15조에 명시될 수 있습니다).
# ...
